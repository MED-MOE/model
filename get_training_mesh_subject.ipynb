# %%
import json

training_json = "pubmedqa/data/ori_pqal.json"
dataset = json.load(open(training_json))

all_meshes = []
for pmid in dataset:
    all_meshes.extend(dataset[pmid]["MESHES"])

# %%
import os

cwd = os.getcwd()
print(cwd)
# Out:
# /home/dyh2111/moeme/model

# %%
all_meshes
# Out:
# ['Alismataceae',
#  'Apoptosis',
#  'Cell Differentiation',
#  'Mitochondria',
#  'Plant Leaves',
#  'Adolescent',
#  'Adult',
#  'Aged',
#  'Aged, 80 and over',
#  'Amblyopia',
#  'Cataract',
#  'Child',
#  'Eye Diseases',
#  'Female',
#  'Humans',
#  'Male',
#  'Middle Aged',
#  'Reference Values',
#  'Refractive Errors',
#  'Reproducibility of Results',
#  'Retinal Diseases',
#  'Strabismus',
#  'Vision Tests',
#  'Visual Acuity',
#  'Baths',
#  'Histamine',
#  'Humans',
#  'Infant',
#  'Syncope',
#  'Urticaria',
#  'Water',
#  'Child',
#  'Child, Preschool',
#  'Colectomy',
#  'Female',
#  'Hirschsprung Disease',
#  'Humans',
#  'Male',
#  'Treatment Outcome',
#  'Cost-Benefit Analysis',
#  'Female',
#  'Health Maintenance Organizations',
#  'Humans',
#  'Logistic Models',
#  'Mammography',
#  'Marketing of Health Services',
#  'Middle Aged',
#  'North Carolina',
#  'Odds Ratio',
#  'Pamphlets',
#  'Patient Acceptance of Health Care',
#  'Patient Satisfaction',
# ...
