# %% [markdown]
# # 🏥 Medical Model Optimization + Mixture of Experts
# ## ⚙️ Notebook 2: Optimization
#
# **Authors:**
# - Dan Harvey
# - Xinzhuo Jiang
#
# **Affiliation:**
# *High-Performance Machine Learning (HPML)*
# *Columbia University*
#
#
# ---
#
# ### 🔍 Project Overview
#
# In this section, we evaluate how quantization affects model load time, memory usage, and inference speed.
#
#
# ### 🎯 Objectives
#
# - Load `Llama-3-8B-UltraMedical` in FP16, 8-bit, and 4-bit quantized formats
# - Time each loading operation
# - Profile memory usage using `nvidia-smi`
# - Compare load time, memory, and performance tradeoffs
#
# We use Hugging Face’s quantization options and BitsAndBytes for INT8/INT4 support.

# %%
## 📦 Environment Setup: Dependencies and Imports

# Install essential packages (example: bitsandbytes)
#!pip install -U bitsandbytes

# Standard library imports
import os
import sys
import gc
import time
import subprocess
import wandb
from datetime import datetime
import importlib
import torch

# Hugging Face imports
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# Ensure project root is in Python path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# List of required packages
required_packages = [
    'torch', 'transformers', 'datasets', 'accelerate', 'flash_attn',
    'evaluate', 'lm_eval', 'sklearn', 'matplotlib', 'wandb',
    'tqdm', 'sentencepiece', 'scipy', 'einops'
]

# Check for installed packages and install missing ones
for package in required_packages:
    try:
        module = importlib.import_module(package)
        print(f"✅ {package} installed successfully")
        if package == 'torch':
            print(f"   Version: {torch.__version__}")
            print(f"   CUDA available: {torch.cuda.is_available()}")
            if torch.cuda.is_available():
                print(f"   CUDA version: {torch.version.cuda}")
                print(f"   GPU: {torch.cuda.get_device_name(0)}")
        elif hasattr(module, '__version__'):
            print(f"   Version: {module.__version__}")
    except ImportError:
        print(f"❌ {package} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        module = importlib.import_module(package)
        print(f"✅ {package} installed successfully (post-install)")
        if hasattr(module, '__version__'):
            print(f"   Version: {module.__version__}")

print("⚠️ You may need to restart the Kernel for some packages to take effect.")
# Out:
# ✅ torch installed successfully
#    Version: 2.6.0+cu124
#    CUDA available: True
#    CUDA version: 12.4
#    GPU: NVIDIA A100-SXM4-40GB
# ✅ transformers installed successfully
#    Version: 4.51.3
# ✅ datasets installed successfully
#    Version: 3.6.0
# ✅ accelerate installed successfully
#    Version: 1.6.0
# ✅ flash_attn installed successfully
#    Version: 2.7.4.post1
# ✅ evaluate installed successfully
#    Version: 0.4.3
# ❌ lm_eval not found. Installing...
# ✅ lm_eval installed successfully (post-install)
# ✅ sklearn installed successfully
#    Version: 1.6.1
# ✅ matplotlib installed successfully
#    Version: 3.10.0
# ✅ wandb installed successfully
#    Version: 0.19.10
# ✅ tqdm installed successfully
#    Version: 4.67.1
# ✅ sentencepiece installed successfully
#    Version: 0.2.0
# ✅ scipy installed successfully
#    Version: 1.15.2
# ✅ einops installed successfully
#    Version: 0.8.1
# ⚠️ You may need to restart the Kernel for some packages to take effect.

# %%
# 🔐 Hugging Face Access - Llama is Gated
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: read).
# The token `helm` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `helm`

# %%
# log into Weights and Biases
# !wandb login --relogin 3114d04ef3f8187e6f6852dd28ede0fa5a2ec32c
# Out:
# wandb: WARNING Using legacy-service, which is deprecated. If this is unintentional, you can fix it by ensuring you do not call `wandb.require('legacy-service')` and do not set the WANDB_X_REQUIRE_LEGACY_SERVICE environment variable.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin

# %%
# Import section dependencies
import platform
import psutil
import distro
import numpy as np

# ==========================
# 🖥️ System & OS Information
# ==========================
system_info = platform.uname()

print("🖥️ System Information")
print("-" * 40)
print(f"Node Name      : {system_info.node}")
print(f"System         : {platform.system()}")
print(f"OS Flavor      : {distro.name()}")
print(f"OS Version     : {distro.version()}")
print(f"Release        : {system_info.release}")
print(f"Architecture   : {platform.machine()}")
print(f"Python Version : {platform.python_version()}")

# =====================
# 🧠 CPU Information
# =====================
cpu_count = psutil.cpu_count(logical=False)
logical_cpu_count = psutil.cpu_count(logical=True)

print("\n🧠 CPU Information")
print("-" * 40)
print(f"Processor      : {system_info.processor or platform.processor()}")
print(f"Physical Cores : {cpu_count}")
print(f"Logical Cores  : {logical_cpu_count}")

# ======================
# 🧠 Memory Information
# ======================
memory_info = psutil.virtual_memory()

print("\n🧠 Memory Information")
print("-" * 40)
print(f"Total RAM      : {memory_info.total / 1024 ** 3:.2f} GB")
print(f"Available RAM  : {memory_info.available / 1024 ** 3:.2f} GB")
print(f"Used RAM       : {memory_info.used / 1024 ** 3:.2f} GB")

# =======================
# 💾 Disk Information
# =======================
disk_info = psutil.disk_usage('/')

print("\n💾 Disk Information")
print("-" * 40)
print(f"Total Space    : {disk_info.total / 1024 ** 3:.2f} GB")
print(f"Used Space     : {disk_info.used / 1024 ** 3:.2f} GB")
print(f"Free Space     : {disk_info.free / 1024 ** 3:.2f} GB")

# =======================
# 🧠 GPU Information
# =======================

print("\n🧠 GPU Info")
print("GPU:", torch.cuda.get_device_name(0))
print("CUDA Available:", True)
# Out:
# 🖥️ System Information
# ----------------------------------------
# Node Name      : 7057e84ce825
# System         : Linux
# OS Flavor      : Ubuntu
# OS Version     : 22.04
# Release        : 6.1.123+
# Architecture   : x86_64
# Python Version : 3.11.12
#
# 🧠 CPU Information
# ----------------------------------------
# Processor      : x86_64
# Physical Cores : 6
# Logical Cores  : 12
#
# 🧠 Memory Information
# ----------------------------------------
# Total RAM      : 83.48 GB
# Available RAM  : 80.69 GB
# Used RAM       : 1.93 GB
#
# 💾 Disk Information
# ----------------------------------------
# Total Space    : 235.68 GB
# Used Space     : 42.50 GB
# Free Space     : 193.16 GB
#
# 🧠 GPU Info
# GPU: NVIDIA A100-SXM4-40GB
# CUDA Available: True

# %% [markdown]
# ## 🦙 Llama-3-8B-UltraMedical
#
# **Links**
# - 🤗 [Hugging Face Model Card](https://huggingface.co/TsinghuaC3I/Llama-3-8B-UltraMedical)
# - 📄 [Paper / Source](https://huggingface.co/TsinghuaC3I/Llama-3-8B-UltraMedical)

# %% [markdown]
# ##Quantization Timing and Benchmarks

# %% [markdown]
# fp32

# %%
## 🦙 Llama-3-8B-UltraMedical: Model Load Benchmark (FP32, 5 Repetitions)

# Model identifier
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

# Load tokenizer once (does not impact model load timings)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
)

# Parameters
total_runs = 6  # Includes warm-up run
timed_runs = total_runs - 1  # Discard first run
load_times = []

print(f"⏳ Starting model load benchmark ({total_runs - 1} timed repetitions)...\n")

# Model load timing loop
for i in range(total_runs):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        torch_dtype=torch.float32,
    )

    elapsed = time.monotonic() - start_time

    if i > 0:  # Skip first run (warm-up/download)
        load_times.append(elapsed)
        print(f"✅ Run {i}: Loaded in {elapsed:.2f} seconds")
    else:
        print(f"⚠️ Warm-up Run {i} completed (not timed)")

    # Show GPU memory on last run
    if i == total_runs - 1:
        print(f"\n📦 GPU Memory Snapshot after final run:")
        print(subprocess.getoutput("nvidia-smi"))

    # Cleanup after each run
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary statistics
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (FP32)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Standard Deviation: {std_dev_time:.2f} seconds")

gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# tokenizer_config.json:   0%|          | 0.00/51.0k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.08M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# ⏳ Starting model load benchmark (5 timed repetitions)...
# config.json:   0%|          | 0.00/728 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/23.9k [00:00<?, ?B/s]
# Fetching 4 files:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/121 [00:00<?, ?B/s]
# ⚠️ Warm-up Run 0 completed (not timed)
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 5.26 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 4.77 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 4.74 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 4.70 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 4.73 seconds
#
# 📦 GPU Memory Snapshot after final run:
# Mon May 12 05:31:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             54W /  400W |   33139MiB /  40960MiB |     34%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (FP32)
# - Average Load Time: 4.84 seconds
# - Standard Deviation: 0.21 seconds

# %% [markdown]
# Benchmarking Test - Normal

# %%
# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"
task_name = "pubmedqa"
output_base = "/content/Results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 32,
        "precision": "fp32",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

config = wandb.config

# -----------------------------
# ⏱️ Timing List to Track Each Run
# -----------------------------
timing_list = []

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(config.repeats):
    print(f"\n🔁 Run {i + 1}/{config.repeats}")

    # Timestamped output directory
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i + 1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},parallelize=True",
        "--device", "cuda:0",
        "--batch_size", str(config.batch_size),
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Run evaluation and time it
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time
    timing_list.append(elapsed)

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)
    print("STDERR:\n", result.stderr)

    # -----------------------------
    # 📊 Parse Evaluation Results
    # -----------------------------
    result_file = next(
        (os.path.join(run_output_dir, f) for f in os.listdir(run_output_dir)
         if f.startswith("eval_results") and f.endswith(".json")),
        None
    )

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

    try:
        with open(result_file, 'r') as f:
            data = json.load(f)

        task_data = data["results"].get(task_name, {})
        acc = task_data.get("acc,none")
        stderr = task_data.get("acc_stderr,none")

        if acc is not None and stderr is not None:
            wandb_run.log({
                f"{task_name}/accuracy": acc,
                f"{task_name}/stddev": stderr,
                f"{task_name}/eval_time_sec": elapsed,
                "run_index": i + 1
            })
            print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")
        else:
            print(f"⚠️ Missing keys in result: {task_data.keys()}")

    except Exception as e:
        print(f"⚠️ Failed to parse results from {result_file}: {e}")

# -----------------------------
# 📊 Final Timing Summary
# -----------------------------
average_time = sum(timing_list) / len(timing_list)
print(f"\n⏱️ Average Evaluation Time over {config.repeats} runs: {average_time:.2f} seconds")

wandb_run.log({
    f"{task_name}/mean_eval_time_sec": average_time
})

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()

# -----------------------------
# 🧹 Final Cleanup
# -----------------------------
gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# wandb: Currently logged in as: xj2193 (med-moe) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250512_053210-fbg9uv3x</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fbg9uv3x' target="_blank">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fbg9uv3x' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fbg9uv3x</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 48.85 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:32:15.443461: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747027935.464665    2892 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747027935.471168    2892 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:32:32,210 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:32:32,211 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:32:32,213 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:32:32,214 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'trust_remote_code': True}
# 2025-05-12:05:32:32,252 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:32:33,086 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.37s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.37s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.36s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.05it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.10s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
#
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating train split: 450 examples [00:00, 9960.82 examples/s]
#
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating validation split: 50 examples [00:00, 7720.34 examples/s]
#
# Generating test split: 0 examples [00:00, ? examples/s]
# Generating test split: 500 examples [00:00, 12180.63 examples/s]
# 2025-05-12:05:32:39,332 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 88862.37it/s]
# 2025-05-12:05:32:39,389 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:32:39,389 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:32:39,389 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:32:39,389 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:32:39,389 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:32:39,390 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:32:39,390 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<58:41,  2.35s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:40, 34.34it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:24, 53.95it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:18, 67.13it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 77.09it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:11, 85.18it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:10, 91.68it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:09<00:08, 97.73it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:10<00:07, 103.07it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 108.83it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 114.39it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:12<00:03, 119.79it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 125.96it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 133.88it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:14<00:01, 142.14it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 169.56it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 103.74it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:32:58,557 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_1_2025-05-12T05-32-11
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 46.70 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:33:04.331320: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747027984.352530    3170 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747027984.358978    3170 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:33:20,967 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:33:20,967 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:33:20,969 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:33:20,969 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'trust_remote_code': True}
# 2025-05-12:05:33:21,007 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:33:21,749 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.37s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.38s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.37s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.05it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:05:33:27,014 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 102410.00it/s]
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:33:27,073 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<51:20,  2.05s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:37, 37.08it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:23, 56.64it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:17, 69.29it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 78.79it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:11, 86.50it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:09, 92.70it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:08<00:08, 98.49it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:09<00:07, 103.63it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 109.26it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 114.68it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:11<00:03, 120.12it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 126.22it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 134.06it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:13<00:01, 142.21it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 169.51it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 105.86it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:33:45,257 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_2_2025-05-12T05-33-00
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 47.09 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:33:50.933531: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747028030.954081    3441 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747028030.960334    3441 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:34:07,463 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:34:07,464 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:34:07,465 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:34:07,465 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'trust_remote_code': True}
# 2025-05-12:05:34:07,504 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:34:08,218 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.36s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.39s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.37s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.05it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:05:34:14,031 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 100270.24it/s]
# 2025-05-12:05:34:14,092 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# ...
# 2025-05-12:05:35:48,786 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:35:48,786 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:35:48,786 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:35:48,786 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:35:48,786 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<50:55,  2.04s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:37, 37.23it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:23, 56.77it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:17, 69.40it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 78.85it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:11, 86.43it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:09, 92.60it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:08<00:08, 98.38it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:09<00:07, 103.51it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 109.13it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 114.56it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:11<00:03, 120.21it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 126.22it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 134.00it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:13<00:01, 142.10it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 169.46it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 105.90it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:36:06,958 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_5_2025-05-12T05-35-21
#
# ⏱️ Average Evaluation Time over 5 runs: 47.45 seconds
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>47.44595</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fbg9uv3x' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fbg9uv3x</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_053210-fbg9uv3x/logs</code>

# %% [markdown]
# FP16 Quantization (float16)

# %%
## 🦙 Llama-3-8B-UltraMedical: Model Load Benchmark (FP32, 5 Repetitions)

# Model identifier
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

# Load tokenizer once (does not impact model load timings)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
)

# Parameters
total_runs = 6  # Includes warm-up run
timed_runs = total_runs - 1  # Discard first run
load_times = []

print(f"⏳ Starting model load benchmark ({total_runs - 1} timed repetitions)...\n")

# Model load timing loop
for i in range(total_runs):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        torch_dtype=torch.float16,
    )

    elapsed = time.monotonic() - start_time

    if i > 0:  # Skip first run (warm-up/download)
        load_times.append(elapsed)
        print(f"✅ Run {i}: Loaded in {elapsed:.2f} seconds")
    else:
        print(f"⚠️ Warm-up Run {i} completed (not timed)")

    # Show GPU memory on last run
    if i == total_runs - 1:
        print(f"\n📦 GPU Memory Snapshot after final run:")
        print(subprocess.getoutput("nvidia-smi"))

    # Cleanup after each run
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary statistics
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (FP32)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Standard Deviation: {std_dev_time:.2f} seconds")

gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# ⏳ Starting model load benchmark (5 timed repetitions)...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ⚠️ Warm-up Run 0 completed (not timed)
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 4.69 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 5.03 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 4.66 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 4.66 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 4.69 seconds
#
# 📦 GPU Memory Snapshot after final run:
# Mon May 12 05:38:46 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             51W /  400W |   17823MiB /  40960MiB |     34%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (FP32)
# - Average Load Time: 4.75 seconds
# - Standard Deviation: 0.14 seconds

# %%
# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"
task_name = "pubmedqa"
output_base = "/content/Results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 32,
        "precision": "fp16",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

config = wandb.config

# -----------------------------
# ⏱️ Timing List to Track Each Run
# -----------------------------
timing_list = []

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(config.repeats):
    print(f"\n🔁 Run {i + 1}/{config.repeats}")

    # Timestamped output directory
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i + 1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},parallelize=True,dtype=float16",
        "--device", "cuda:0",
        "--batch_size", str(config.batch_size),
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Run evaluation and time it
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time
    timing_list.append(elapsed)

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)
    print("STDERR:\n", result.stderr)

    # -----------------------------
    # 📊 Parse Evaluation Results
    # -----------------------------
    result_file = next(
        (os.path.join(run_output_dir, f) for f in os.listdir(run_output_dir)
         if f.startswith("eval_results") and f.endswith(".json")),
        None
    )

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

    try:
        with open(result_file, 'r') as f:
            data = json.load(f)

        task_data = data["results"].get(task_name, {})
        acc = task_data.get("acc,none")
        stderr = task_data.get("acc_stderr,none")

        if acc is not None and stderr is not None:
            wandb_run.log({
                f"{task_name}/accuracy": acc,
                f"{task_name}/stddev": stderr,
                f"{task_name}/eval_time_sec": elapsed,
                "run_index": i + 1
            })
            print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")
        else:
            print(f"⚠️ Missing keys in result: {task_data.keys()}")

    except Exception as e:
        print(f"⚠️ Failed to parse results from {result_file}: {e}")

# -----------------------------
# 📊 Final Timing Summary
# -----------------------------
average_time = sum(timing_list) / len(timing_list)
print(f"\n⏱️ Average Evaluation Time over {config.repeats} runs: {average_time:.2f} seconds")

wandb_run.log({
    f"{task_name}/mean_eval_time_sec": average_time
})

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()

# -----------------------------
# 🧹 Final Cleanup
# -----------------------------
gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5kmp0485' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5kmp0485</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_054813-5kmp0485/logs</code>
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250512_054827-5b6x4lsb</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5b6x4lsb' target="_blank">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5b6x4lsb' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5b6x4lsb</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 47.75 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,dtype=float16,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:48:32.995897: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747028913.017590    8164 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747028913.024195    8164 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:48:49,499 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:48:49,499 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:48:49,501 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:48:49,501 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'dtype': 'float16', 'trust_remote_code': True}
# 2025-05-12:05:48:49,540 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:48:50,323 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.39s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.40s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.38s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.04it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:05:48:56,159 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 94377.03it/s]
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:48:56,219 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<53:17,  2.13s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:39, 35.70it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:24, 54.44it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:18, 66.52it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 75.60it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:12, 83.04it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:10, 89.02it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:09<00:08, 94.72it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:10<00:07, 99.97it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:06, 105.31it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 110.38it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:12<00:03, 115.59it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:13<00:02, 121.42it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 129.13it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:14<00:01, 137.40it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 164.07it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 101.93it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:49:14,949 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_1_2025-05-12T05-48-28
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 47.49 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,dtype=float16,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:49:20.826124: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747028960.846914    8438 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747028960.853220    8438 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:49:37,446 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:49:37,446 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:49:37,448 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:49:37,448 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'dtype': 'float16', 'trust_remote_code': True}
# 2025-05-12:05:49:37,487 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:49:38,257 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.40s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.40s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.39s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.04it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:05:49:43,593 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 96142.30it/s]
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:49:43,654 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<52:37,  2.11s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:39, 35.94it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:23, 54.65it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:18, 66.68it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 75.74it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:12, 83.16it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:10, 89.18it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:09<00:08, 94.72it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:10<00:07, 100.06it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:06, 105.37it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 110.44it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:12<00:03, 115.57it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:13<00:02, 121.27it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 129.02it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:14<00:01, 137.31it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 164.26it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 102.11it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:50:02,382 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_2_2025-05-12T05-49-16
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 47.50 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,dtype=float16,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# STDERR:
#  2025-05-12 05:50:08.243000: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747029008.264207    8714 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747029008.270649    8714 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:05:50:24,895 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:05:50:24,895 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:05:50:24,896 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:05:50:24,896 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'dtype': 'float16', 'trust_remote_code': True}
# 2025-05-12:05:50:24,936 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:05:50:25,693 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.39s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.40s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.39s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.04it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:05:50:31,109 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 95651.17it/s]
# 2025-05-12:05:50:31,167 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# ...
# 2025-05-12:05:52:05,768 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:52:05,768 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:52:05,768 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:05:52:05,768 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:05:52:05,769 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<53:13,  2.13s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:39, 35.68it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:24, 54.38it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:18, 66.47it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:14, 75.60it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:12, 83.00it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:08<00:10, 89.06it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:09<00:08, 94.65it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:10<00:07, 99.97it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:06, 105.21it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:11<00:04, 110.26it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:12<00:03, 115.40it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:13<00:02, 121.12it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:13<00:01, 128.89it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:14<00:01, 137.19it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:14<00:00, 164.13it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:14<00:00, 101.87it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:05:52:24,574 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_5_2025-05-12T05-51-38
#
# ⏱️ Average Evaluation Time over 5 runs: 47.47 seconds
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>47.46859</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5b6x4lsb' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/5b6x4lsb</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_054827-5b6x4lsb/logs</code>

# %% [markdown]
# Int8

# %%
import time
import gc
import subprocess
import numpy as np
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

# -----------------------------
# 🦙 Llama-3-8B-UltraMedical: Model Load Benchmark (Int8, 5 Repetitions)
# -----------------------------

# Model identifier
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

# Load tokenizer once (does not impact model load timings)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
)

# BitsAndBytes int8 quantization config
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True,
    llm_int8_threshold=6.0
)

# Parameters
total_runs = 6  # Includes warm-up run
load_times = []

print(f"⏳ Starting model load benchmark in Int8 ({total_runs - 1} timed repetitions)...\n")

# Model load timing loop
for i in range(total_runs):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        quantization_config=bnb_config
    )

    elapsed = time.monotonic() - start_time

    if i > 0:  # Skip first run (warm-up/download)
        load_times.append(elapsed)
        print(f"✅ Run {i}: Loaded in {elapsed:.2f} seconds")
    else:
        print(f"⚠️ Warm-up Run {i} completed (not timed)")

    # Show GPU memory on last run
    if i == total_runs - 1:
        print(f"\n📦 GPU Memory Snapshot after final run:")
        print(subprocess.getoutput("nvidia-smi"))

    # Cleanup after each run
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary statistics
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (Int8 Quantized)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Standard Deviation: {std_dev_time:.2f} seconds")

# Final Cleanup
gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# ⏳ Starting model load benchmark in Int8 (5 timed repetitions)...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ⚠️ Warm-up Run 0 completed (not timed)
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 17.70 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 17.71 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 17.85 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 17.73 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 17.79 seconds
#
# 📦 GPU Memory Snapshot after final run:
# Mon May 12 05:56:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             51W /  400W |   10393MiB /  40960MiB |     16%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (Int8 Quantized)
# - Average Load Time: 17.75 seconds
# - Standard Deviation: 0.06 seconds

# %% [markdown]
# **🔍 INT8 Quantization (int8)**

# %%
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

from transformers import BitsAndBytesConfig

# 8-bit quantization config
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True
)

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_auth_token=True
)

load_times = []

trials = 5

print(f"⏳ Starting timed model loads ({trials} repetitions)...\n")

for i in range(trials):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        quantization_config=bnb_config,
        use_auth_token=True
    )

    elapsed = time.monotonic() - start_time
    load_times.append(elapsed)
    print(f"✅ Run {i + 1}: Loaded in {elapsed:.2f} seconds")

    if i == trials - 1:
        print(f"\n📦 GPU Memory Snapshot:")
        print(subprocess.getoutput("nvidia-smi"))

    # Clean up between runs (free GPU memory)
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary stats
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (INT8)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Std Dev:           {std_dev_time:.2f} seconds")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ⏳ Starting timed model loads (5 repetitions)...
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 18.04 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 17.54 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 17.08 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 16.79 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 17.11 seconds
#
# 📦 GPU Memory Snapshot:
# Mon May 12 06:11:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   29C    P0             51W /  400W |   10393MiB /  40960MiB |     22%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (INT8)
# - Average Load Time: 17.31 seconds
# - Std Dev:           0.43 seconds

# %%
# Benchmark Int8
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime
import lm_eval

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x_int8"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 8,
        "precision": "int8",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    day = datetime.now().strftime("%Y-%m-%d")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command for Int8 quantization
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True",
        "--device", "cuda:0",
        "--batch_size", "8",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    subfolder = model_name.replace('/', '__')
    result_dir = os.path.join(run_output_dir, subfolder)

    if os.path.exists(result_dir):
        for fname in os.listdir(result_dir):
            print(fname)
            if fname.startswith(f"results_{day}") and fname.endswith(".json"):
                result_file = os.path.join(result_dir, fname)
                with open(result_file, 'r') as f:
                    result = json.load(f)
                    acc = result['results'][task_name]['acc,none']
                    stderr = result['results'][task_name]['acc_stderr,none']

                    wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                                   f"{task_name}/accuracy": acc,
                                   f"{task_name}/stderr": stderr,
                                   "run_index": i + 1
                                   })
                    print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {result_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_5x_int8</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/gvyuu40k' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/gvyuu40k</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_062242-gvyuu40k/logs</code>
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250512_062411-bv6vbztj</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/bv6vbztj' target="_blank">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x_int8</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/bv6vbztj' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/bv6vbztj</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 71.39 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# results_2025-05-12T06-25-24.795592.json
# 📈 Logged to W&B: acc=0.758, stderr=0.0192
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 71.29 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# results_2025-05-12T06-26-36.077327.json
# 📈 Logged to W&B: acc=0.758, stderr=0.0192
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 72.57 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# results_2025-05-12T06-27-48.646176.json
# 📈 Logged to W&B: acc=0.758, stderr=0.0192
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 71.37 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# results_2025-05-12T06-28-59.990701.json
# 📈 Logged to W&B: acc=0.758, stderr=0.0192
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 71.15 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_8bit=True,llm_int8_enable_fp32_cpu_offload=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.758|±  |0.0192|
#
#
# results_2025-05-12T06-30-11.137789.json
# 📈 Logged to W&B: acc=0.758, stderr=0.0192
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>▂▂█▂▁</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.758</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>71.1463</td></tr><tr><td>pubmedqa/stderr</td><td>0.01917</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x_int8</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/bv6vbztj' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/bv6vbztj</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_062411-bv6vbztj/logs</code>

# %% [markdown]
# Int4

# %% [markdown]
# **🔍 INT4 Quantization (int4)**

# %%
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

from transformers import BitsAndBytesConfig

# 4-bit quantization config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    llm_int4_enable_fp32_cpu_offload=True
)

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_auth_token=True
)

load_times = []

trials = 5

print(f"⏳ Starting timed model loads ({trials} repetitions)...\n")

for i in range(trials):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        quantization_config=bnb_config,
    )

    elapsed = time.monotonic() - start_time
    load_times.append(elapsed)
    print(f"✅ Run {i + 1}: Loaded in {elapsed:.2f} seconds")

    if i == trials - 1:
        print(f"\n📦 GPU Memory Snapshot:")
        print(subprocess.getoutput("nvidia-smi"))

    # Clean up between runs (free GPU memory)
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary stats
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (INT4)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Std Dev:           {std_dev_time:.2f} seconds")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ⏳ Starting timed model loads (5 repetitions)...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 18.29 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 17.72 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 17.73 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 17.70 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 17.79 seconds
#
# 📦 GPU Memory Snapshot:
# Mon May 12 06:32:05 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             52W /  400W |    8241MiB /  40960MiB |      9%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (INT4)
# - Average Load Time: 17.84 seconds
# - Std Dev:           0.22 seconds

# %%
# Benchmark Int4
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime
import lm_eval

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x_int4"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 8,
        "precision": "int4",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    day = datetime.now().strftime("%Y-%m-%d")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command for Int4 quantization
    model_args_str = (
        f"pretrained={model_name},"
        "parallelize=True,"
        "load_in_4bit=True,"
        "bnb_4bit_compute_dtype=float16,"
        "bnb_4bit_quant_type=nf4,"
        "bnb_4bit_use_double_quant=True"
    )

    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", model_args_str,
        "--device", "cuda:0",
        "--batch_size", "8",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    subfolder = model_name.replace('/', '__')
    result_dir = os.path.join(run_output_dir, subfolder)

    if os.path.exists(result_dir):
        for fname in os.listdir(result_dir):
            print(fname)
            if fname.startswith(f"results_{day}") and fname.endswith(".json"):
                result_file = os.path.join(result_dir, fname)
                with open(result_file, 'r') as f:
                    result = json.load(f)
                    acc = result['results'][task_name]['acc,none']
                    stderr = result['results'][task_name]['acc_stderr,none']

                    wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                                   f"{task_name}/accuracy": acc,
                                   f"{task_name}/stderr": stderr,
                                   "run_index": i + 1
                                   })
                    print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {result_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250512_063518-m9r1fqaf</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/m9r1fqaf' target="_blank">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x_int4</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/m9r1fqaf' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/m9r1fqaf</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 61.89 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_4bit=True,bnb_4bit_compute_dtype=float16,bnb_4bit_quant_type=nf4,bnb_4bit_use_double_quant=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.746|±  |0.0195|
#
#
# results_2025-05-12T06-36-20.344462.json
# 📈 Logged to W&B: acc=0.746, stderr=0.0195
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 62.22 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_4bit=True,bnb_4bit_compute_dtype=float16,bnb_4bit_quant_type=nf4,bnb_4bit_use_double_quant=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.746|±  |0.0195|
#
#
# results_2025-05-12T06-37-22.519636.json
# 📈 Logged to W&B: acc=0.746, stderr=0.0195
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 62.43 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_4bit=True,bnb_4bit_compute_dtype=float16,bnb_4bit_quant_type=nf4,bnb_4bit_use_double_quant=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.746|±  |0.0195|
#
#
# results_2025-05-12T06-38-24.963035.json
# 📈 Logged to W&B: acc=0.746, stderr=0.0195
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 62.04 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_4bit=True,bnb_4bit_compute_dtype=float16,bnb_4bit_quant_type=nf4,bnb_4bit_use_double_quant=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.746|±  |0.0195|
#
#
# results_2025-05-12T06-39-26.991878.json
# 📈 Logged to W&B: acc=0.746, stderr=0.0195
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 62.10 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,load_in_4bit=True,bnb_4bit_compute_dtype=float16,bnb_4bit_quant_type=nf4,bnb_4bit_use_double_quant=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.746|±  |0.0195|
#
#
# results_2025-05-12T06-40-29.102973.json
# 📈 Logged to W&B: acc=0.746, stderr=0.0195
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>▁▅█▃▄</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.746</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>62.10305</td></tr><tr><td>pubmedqa/stderr</td><td>0.01949</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x_int4</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/m9r1fqaf' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/m9r1fqaf</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_063518-m9r1fqaf/logs</code>

# %% [markdown]
# ## Flash Attention

# %%
#Flash Attention
# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"
task_name = "pubmedqa"
output_base = "/content/Results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 32,
        "precision": "fp32",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

config = wandb.config

# -----------------------------
# ⏱️ Timing List to Track Each Run
# -----------------------------
timing_list = []

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(config.repeats):
    print(f"\n🔁 Run {i + 1}/{config.repeats}")

    # Timestamped output directory
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i + 1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    # Define lm_eval command with FlashAttention 2 enabled
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},parallelize=True,attn_implementation=flash_attention_2",
        "--device", "cuda:0",
        "--batch_size", str(config.batch_size),
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]


    # Run evaluation and time it
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time
    timing_list.append(elapsed)

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)
    print("STDERR:\n", result.stderr)

    # -----------------------------
    # 📊 Parse Evaluation Results
    # -----------------------------
    result_file = next(
        (os.path.join(run_output_dir, f) for f in os.listdir(run_output_dir)
         if f.startswith("eval_results") and f.endswith(".json")),
        None
    )

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

    try:
        with open(result_file, 'r') as f:
            data = json.load(f)

        task_data = data["results"].get(task_name, {})
        acc = task_data.get("acc,none")
        stderr = task_data.get("acc_stderr,none")

        if acc is not None and stderr is not None:
            wandb_run.log({
                f"{task_name}/accuracy": acc,
                f"{task_name}/stddev": stderr,
                f"{task_name}/eval_time_sec": elapsed,
                "run_index": i + 1
            })
            print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")
        else:
            print(f"⚠️ Missing keys in result: {task_data.keys()}")

    except Exception as e:
        print(f"⚠️ Failed to parse results from {result_file}: {e}")

# -----------------------------
# 📊 Final Timing Summary
# -----------------------------
average_time = sum(timing_list) / len(timing_list)
print(f"\n⏱️ Average Evaluation Time over {config.repeats} runs: {average_time:.2f} seconds")

wandb_run.log({
    f"{task_name}/mean_eval_time_sec": average_time
})

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()

# -----------------------------
# 🧹 Final Cleanup
# -----------------------------
gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250512_070521-6w5q6dh8</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/6w5q6dh8' target="_blank">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/6w5q6dh8' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/6w5q6dh8</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 46.64 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.762|±  |0.0191|
#
#
# STDERR:
#  2025-05-12 07:05:27.530588: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747033527.552053   29822 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747033527.558662   29822 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:07:05:44,162 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:07:05:44,162 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:07:05:44,164 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:07:05:44,164 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'attn_implementation': 'flash_attention_2', 'trust_remote_code': True}
# 2025-05-12:07:05:44,204 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:07:05:44,993 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.39s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.40s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.39s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.04it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.12s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:07:05:50,375 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 99485.39it/s]
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:05:50,436 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<50:04,  2.00s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:36, 38.10it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:22, 58.28it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:16, 71.34it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:13, 81.07it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:06<00:11, 89.00it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:07<00:09, 95.38it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:08<00:08, 101.33it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:09<00:06, 106.66it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 112.40it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:10<00:04, 117.95it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:11<00:03, 123.45it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 129.71it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:12<00:01, 137.75it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:13<00:01, 146.09it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:13<00:00, 173.78it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:13<00:00, 108.81it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:07:06:08,316 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_1_2025-05-12T07-05-23
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 46.57 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.762|±  |0.0191|
#
#
# STDERR:
#  2025-05-12 07:06:14.158780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747033574.181034   30092 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747033574.187559   30092 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:07:06:30,678 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:07:06:30,679 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:07:06:30,680 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:07:06:30,680 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'attn_implementation': 'flash_attention_2', 'trust_remote_code': True}
# 2025-05-12:07:06:30,719 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:07:06:31,660 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.37s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.39s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.38s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.04it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:07:06:37,116 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 93227.47it/s]
# 2025-05-12:07:06:37,176 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:06:37,176 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' yes'), idx=0, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:06:37,177 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:06:37,177 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:06:37,177 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:06:37,177 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:06:37,177 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<50:00,  2.00s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:36, 38.05it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:22, 58.23it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:16, 71.33it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:13, 81.13it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:06<00:11, 88.96it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:07<00:09, 95.32it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:08<00:08, 101.30it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:09<00:06, 106.63it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 112.39it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:10<00:04, 117.94it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:11<00:03, 123.49it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 129.69it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:12<00:01, 137.72it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:13<00:01, 146.05it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:13<00:00, 173.36it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:13<00:00, 108.76it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:07:06:54,973 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_2_2025-05-12T07-06-10
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 46.44 seconds
# STDOUT:
#  hf (pretrained=TsinghuaC3I/Llama-3-8B-UltraMedical,parallelize=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.762|±  |0.0191|
#
#
# STDERR:
#  2025-05-12 07:07:00.738384: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747033620.759283   30362 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747033620.765633   30362 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12:07:07:17,497 INFO     [lm_eval.__main__:368] Passed `--trust_remote_code`, setting environment variable `HF_DATASETS_TRUST_REMOTE_CODE=true`
# 2025-05-12:07:07:17,497 INFO     [lm_eval.__main__:379] Selected Tasks: ['pubmedqa']
# 2025-05-12:07:07:17,498 INFO     [lm_eval.evaluator:169] Setting random seed to 0 | Setting numpy seed to 1234 | Setting torch manual seed to 1234 | Setting fewshot manual seed to 1234
# 2025-05-12:07:07:17,498 INFO     [lm_eval.evaluator:206] Initializing hf model, with arguments: {'pretrained': 'TsinghuaC3I/Llama-3-8B-UltraMedical', 'parallelize': True, 'attn_implementation': 'flash_attention_2', 'trust_remote_code': True}
# 2025-05-12:07:07:17,538 INFO     [lm_eval.models.huggingface:153] Using `accelerate launch` or `parallelize=True`, device 'cuda:0' will be overridden when placing model.
# 2025-05-12:07:07:18,319 INFO     [lm_eval.models.huggingface:359] Model parallel was set to True, setting max memory per GPU to {0: 41509191680} and device map to auto
#
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Loading checkpoint shards:  25%|██▌       | 1/4 [00:01<00:04,  1.37s/it]
# Loading checkpoint shards:  50%|█████     | 2/4 [00:02<00:02,  1.38s/it]
# Loading checkpoint shards:  75%|███████▌  | 3/4 [00:04<00:01,  1.37s/it]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.05it/s]
# Loading checkpoint shards: 100%|██████████| 4/4 [00:04<00:00,  1.11s/it]
# /usr/local/lib/python3.11/dist-packages/datasets/load.py:1231: FutureWarning: The repository for bigbio/pubmed_qa contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/bigbio/pubmed_qa
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# 2025-05-12:07:07:23,532 INFO     [lm_eval.api.task:420] Building contexts for pubmedqa on rank 0...
#
#   0%|          | 0/500 [00:00<?, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 99627.17it/s]
# 2025-05-12:07:07:23,592 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# ...
# 2025-05-12:07:08:56,503 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:08:56,503 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' no'), idx=1, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:08:56,503 INFO     [lm_eval.evaluator_utils:206] Task: ConfigurableTask(task_name=pubmedqa,output_type=multiple_choice,num_fewshot=0,num_samples=500); document 0; context prompt (starting on next line):
# Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.
# Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.
# The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.
# Question: Is anorectal endosonography valuable in dyschesia?
# Answer:
# (end of prompt on previous line)
# target string or answer choice index (starting on next line):
# yes
# (end of target on previous line)
# 2025-05-12:07:08:56,504 INFO     [lm_eval.evaluator_utils:210] Request: Instance(request_type='loglikelihood', doc={'QUESTION': 'Is anorectal endosonography valuable in dyschesia?', 'CONTEXTS': ['Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.', 'Twenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.', 'The anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.'], 'LABELS': ['AIMS', 'METHODS', 'RESULTS'], 'MESHES': ['Adolescent', 'Adult', 'Aged', 'Aged, 80 and over', 'Anal Canal', 'Case-Control Studies', 'Chi-Square Distribution', 'Constipation', 'Defecation', 'Endosonography', 'Female', 'Humans', 'Male', 'Middle Aged', 'Pelvic Floor', 'Rectum'], 'YEAR': '2002', 'reasoning_required_pred': 'yes', 'reasoning_free_pred': 'yes', 'final_decision': 'yes', 'LONG_ANSWER': 'Linear anorectal endosonography demonstrated incomplete or even absent relaxation of the anal sphincter and the m. puborectalis during a defecation movement in the majority of our patients with dyschesia. This study highlights the value of this elegant ultrasonographic technique in the diagnosis of "pelvic floor dyssynergia" or "anismus".'}, arguments=('Abstract: Dyschesia can be provoked by inappropriate defecation movements. The aim of this prospective study was to demonstrate dysfunction of the anal sphincter and/or the musculus (m.) puborectalis in patients with dyschesia using anorectal endosonography.\nTwenty consecutive patients with a medical history of dyschesia and a control group of 20 healthy subjects underwent linear anorectal endosonography (Toshiba models IUV 5060 and PVL-625 RT). In both groups, the dimensions of the anal sphincter and the m. puborectalis were measured at rest, and during voluntary squeezing and straining. Statistical analysis was performed within and between the two groups.\nThe anal sphincter became paradoxically shorter and/or thicker during straining (versus the resting state) in 85% of patients but in only 35% of control subjects. Changes in sphincter length were statistically significantly different (p<0.01, chi(2) test) in patients compared with control subjects. The m. puborectalis became paradoxically shorter and/or thicker during straining in 80% of patients but in only 30% of controls. Both the changes in length and thickness of the m. puborectalis were significantly different (p<0.01, chi(2) test) in patients versus control subjects.\nQuestion: Is anorectal endosonography valuable in dyschesia?\nAnswer:', ' maybe'), idx=2, metadata=('pubmedqa', 0, 1), resps=[], filtered_resps={}, task_name='pubmedqa', doc_id=0, repeats=1)
# 2025-05-12:07:08:56,504 INFO     [lm_eval.evaluator:517] Running loglikelihood requests
#
# Running loglikelihood requests:   0%|          | 0/1500 [00:00<?, ?it/s]
# Running loglikelihood requests:   0%|          | 1/1500 [00:02<50:19,  2.01s/it]
# Running loglikelihood requests:   6%|▋         | 97/1500 [00:03<00:36, 37.92it/s]
# Running loglikelihood requests:  13%|█▎        | 193/1500 [00:04<00:22, 58.06it/s]
# Running loglikelihood requests:  19%|█▉        | 289/1500 [00:05<00:17, 71.12it/s]
# Running loglikelihood requests:  26%|██▌       | 385/1500 [00:06<00:13, 80.86it/s]
# Running loglikelihood requests:  32%|███▏      | 481/1500 [00:07<00:11, 88.71it/s]
# Running loglikelihood requests:  38%|███▊      | 577/1500 [00:07<00:09, 95.16it/s]
# Running loglikelihood requests:  45%|████▍     | 673/1500 [00:08<00:08, 101.14it/s]
# Running loglikelihood requests:  51%|█████▏    | 769/1500 [00:09<00:06, 106.49it/s]
# Running loglikelihood requests:  58%|█████▊    | 865/1500 [00:10<00:05, 112.33it/s]
# Running loglikelihood requests:  64%|██████▍   | 961/1500 [00:10<00:04, 118.07it/s]
# Running loglikelihood requests:  70%|███████   | 1057/1500 [00:11<00:03, 123.32it/s]
# Running loglikelihood requests:  77%|███████▋  | 1153/1500 [00:12<00:02, 129.66it/s]
# Running loglikelihood requests:  83%|████████▎ | 1249/1500 [00:12<00:01, 137.67it/s]
# Running loglikelihood requests:  90%|████████▉ | 1345/1500 [00:13<00:01, 145.91it/s]
# Running loglikelihood requests:  96%|█████████▌| 1441/1500 [00:13<00:00, 173.74it/s]
# Running loglikelihood requests: 100%|██████████| 1500/1500 [00:13<00:00, 108.61it/s]
# fatal: not a git repository (or any of the parent directories): .git
# 2025-05-12:07:09:14,380 INFO     [lm_eval.loggers.evaluation_tracker:209] Saving results aggregated
#
# ❌ No eval_results_*.json found in /content/Results/run_5_2025-05-12T07-08-29
#
# ⏱️ Average Evaluation Time over 5 runs: 46.52 seconds
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/mean_eval_time_sec</td><td>46.52424</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">TsinghuaC3I_Llama-3-8B-UltraMedical_pubmedqa_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/6w5q6dh8' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/6w5q6dh8</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250512_070521-6w5q6dh8/logs</code>
