# %% [markdown]
# # 🏥 Medical Model Optimization + Mixture of Experts
# ## ⚙️ Notebook 2: Optimization
#
# **Authors:**
# - Dan Harvey
# - Xinzhuo Jiang
#
# **Affiliation:**
# *High-Performance Machine Learning (HPML)*
# *Columbia University*
#
#
# ---
#
# ### 🔍 Project Overview
#
# In this section, we evaluate how quantization affects model load time, memory usage, and inference speed.
#
#
# ### 🎯 Objectives
#
# - Load `Llama-3-8B-UltraMedical` in FP16, 8-bit, and 4-bit quantized formats
# - Time each loading operation
# - Profile memory usage using `nvidia-smi`
# - Compare load time, memory, and performance tradeoffs
#
# We use Hugging Face’s quantization options and BitsAndBytes for INT8/INT4 support.

# %%
## 📦 Environment Setup: Dependencies and Imports

import torch
import time
import os
import subprocess
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import BitsAndBytesConfig
import gc
import sys
import importlib
# !pip install -U bitsandbytes
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (0.45.5)
# Requirement already satisfied: torch<3,>=2.0 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.6.0+cu124)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3,>=2.0->bitsandbytes) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3,>=2.0->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3,>=2.0->bitsandbytes) (3.0.2)

# %%
# Add project root to path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

# Required packages
required_packages = [
    'torch', 'transformers', 'datasets', 'accelerate', 'flash_attn',
    'evaluate', 'lm_eval', 'sklearn', 'matplotlib', 'wandb',
    'tqdm', 'sentencepiece', 'scipy', 'einops'
]

# Check and install missing packages
for package in required_packages:
    try:
        module = importlib.import_module(package)
        print(f"✅ {package} installed successfully")
        if package == 'torch':
            print(f"   Version: {torch.__version__}")
            print(f"   CUDA available: {torch.cuda.is_available()}")
            if torch.cuda.is_available():
                print(f"   CUDA version: {torch.version.cuda}")
                print(f"   GPU: {torch.cuda.get_device_name(0)}")
        elif hasattr(module, '__version__'):
            print(f"   Version: {module.__version__}")
    except ImportError:
        print(f"❌ {package} not found. Installing...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", package])
        module = importlib.import_module(package)
        print(f"✅ {package} installed successfully (post-install)")
        if hasattr(module, '__version__'):
            print(f"   Version: {module.__version__}")

# You may need to restart the Kernel to use these
# Out:
# ✅ torch installed successfully
#    Version: 2.6.0+cu124
#    CUDA available: True
#    CUDA version: 12.4
#    GPU: NVIDIA A100-SXM4-40GB
# ✅ transformers installed successfully
#    Version: 4.51.3
# ✅ datasets installed successfully
#    Version: 3.6.0
# ✅ accelerate installed successfully
#    Version: 1.6.0
# ✅ flash_attn installed successfully
#    Version: 2.7.4.post1
# ✅ evaluate installed successfully
#    Version: 0.4.3
# ✅ lm_eval installed successfully
# ✅ sklearn installed successfully
#    Version: 1.6.1
# ✅ matplotlib installed successfully
#    Version: 3.10.0
# ✅ wandb installed successfully
#    Version: 0.19.10
# ✅ tqdm installed successfully
#    Version: 4.67.1
# ✅ sentencepiece installed successfully
#    Version: 0.2.0
# ✅ scipy installed successfully
#    Version: 1.15.2
# ✅ einops installed successfully
#    Version: 0.8.1

# %%
# Load section dependencies
from transformers import AutoTokenizer, AutoModelForCausalLM
import gc

# %%
# 🔐 Hugging Face Access - Llama is Gated
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     A token is already saved on your machine. Run `huggingface-cli whoami` to get more information or `huggingface-cli logout` if you want to log out.
#     Setting a new token will erase the existing one.
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `hpml_token` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `hpml_token`

# %%
# Import section dependencies
import platform
import psutil
import distro
import numpy as np

# ==========================
# 🖥️ System & OS Information
# ==========================
system_info = platform.uname()

print("🖥️ System Information")
print("-" * 40)
print(f"Node Name      : {system_info.node}")
print(f"System         : {platform.system()}")
print(f"OS Flavor      : {distro.name()}")
print(f"OS Version     : {distro.version()}")
print(f"Release        : {system_info.release}")
print(f"Architecture   : {platform.machine()}")
print(f"Python Version : {platform.python_version()}")

# =====================
# 🧠 CPU Information
# =====================
cpu_count = psutil.cpu_count(logical=False)
logical_cpu_count = psutil.cpu_count(logical=True)

print("\n🧠 CPU Information")
print("-" * 40)
print(f"Processor      : {system_info.processor or platform.processor()}")
print(f"Physical Cores : {cpu_count}")
print(f"Logical Cores  : {logical_cpu_count}")

# ======================
# 🧠 Memory Information
# ======================
memory_info = psutil.virtual_memory()

print("\n🧠 Memory Information")
print("-" * 40)
print(f"Total RAM      : {memory_info.total / 1024 ** 3:.2f} GB")
print(f"Available RAM  : {memory_info.available / 1024 ** 3:.2f} GB")
print(f"Used RAM       : {memory_info.used / 1024 ** 3:.2f} GB")

# =======================
# 💾 Disk Information
# =======================
disk_info = psutil.disk_usage('/')

print("\n💾 Disk Information")
print("-" * 40)
print(f"Total Space    : {disk_info.total / 1024 ** 3:.2f} GB")
print(f"Used Space     : {disk_info.used / 1024 ** 3:.2f} GB")
print(f"Free Space     : {disk_info.free / 1024 ** 3:.2f} GB")

# =======================
# 🧠 GPU Information
# =======================

print("\n🧠 GPU Info")
print("GPU:", torch.cuda.get_device_name(0))
print("CUDA Available:", True)
# Out:
# 🖥️ System Information
# ----------------------------------------
# Node Name      : 0df102dc8898
# System         : Linux
# OS Flavor      : Ubuntu
# OS Version     : 22.04
# Release        : 6.1.123+
# Architecture   : x86_64
# Python Version : 3.11.12
#
# 🧠 CPU Information
# ----------------------------------------
# Processor      : x86_64
# Physical Cores : 6
# Logical Cores  : 12
#
# 🧠 Memory Information
# ----------------------------------------
# Total RAM      : 83.48 GB
# Available RAM  : 80.90 GB
# Used RAM       : 1.71 GB
#
# 💾 Disk Information
# ----------------------------------------
# Total Space    : 235.68 GB
# Used Space     : 63.25 GB
# Free Space     : 172.41 GB
#
# 🧠 GPU Info
# GPU: NVIDIA A100-SXM4-40GB
# CUDA Available: True

# %% [markdown]
# ## 🦙 Llama-3-8B-UltraMedical
#
# **Links**
# - 🤗 [Hugging Face Model Card](https://huggingface.co/TsinghuaC3I/Llama-3-8B-UltraMedical)
# - 📄 [Paper / Source](https://huggingface.co/TsinghuaC3I/Llama-3-8B-UltraMedical)
#
# **Approximate GPU Memory Requirements:**
# - **FP32**: ~32.4 GB
# - **FP16**: ~48 GB
# - **INT8**: ~24 GB
# - **INT4**: ~12 GB
#
# > These values are estimates and may vary based on sequence length, attention optimizations, and tokenizer overhead.

# %% [markdown]
# ### 🦙 Llama-3-8B-UltraMedical
#
# **🔍 FP16 Quantization (float16)**

# %%
#Llama-3-8B-UltraMedical

model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained("TsinghuaC3I/Llama-3-8B-UltraMedical",
    trust_remote_code=True,
    use_auth_token=True
)

model = AutoModelForCausalLM.from_pretrained("TsinghuaC3I/Llama-3-8B-UltraMedical",
    trust_remote_code=True,
    device_map="auto",
    torch_dtype=torch.float16,
    use_auth_token=True
)

print("✅ Loaded Llama-3-8B-UltraMedical (FP16, device-mapped)")

print("\n📦 GPU Memory Snapshot:")
print(subprocess.getoutput("nvidia-smi"))

# Cleanup
del model
del tokenizer

gc.collect()
torch.cuda.empty_cache()
time.sleep(5)
gc.collect()
torch.cuda.empty_cache()
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Loaded Llama-3-8B-UltraMedical (FP16, device-mapped)
#
# 📦 GPU Memory Snapshot:
# Thu May  8 02:47:28 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             54W /  400W |   17823MiB /  40960MiB |     27%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
#model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_auth_token=True
)

load_times = []

trials = 5

print(f"⏳ Starting timed model loads ({trials} repetitions)...\n")

for i in range(trials):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        torch_dtype=torch.float16,
        use_auth_token=True
    )

    elapsed = time.monotonic() - start_time
    load_times.append(elapsed)
    print(f"✅ Run {i + 1}: Loaded in {elapsed:.2f} seconds")

    if i == trials - 1:
        print(f"\n📦 GPU Memory Snapshot:")
        print(subprocess.getoutput("nvidia-smi"))

    # Clean up between runs (free GPU memory)
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary stats
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (FP16)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Std Dev:           {std_dev_time:.2f} seconds")
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/tokenization_auto.py:898: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# ⏳ Starting timed model loads (5 repetitions)...
# /usr/local/lib/python3.11/dist-packages/transformers/models/auto/auto_factory.py:476: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 4.65 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 5.16 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 4.77 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 4.65 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 4.67 seconds
#
# 📦 GPU Memory Snapshot:
# Thu May  8 02:55:34 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             54W /  400W |   17823MiB /  40960MiB |     35%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (FP16)
# - Average Load Time: 4.78 seconds
# - Std Dev:           0.20 seconds

# %%
# Benchmark fp16
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime
import lm_eval

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "meta-llama/Llama-3.2-3B"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 8,
        "precision": "fp16",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    day = datetime.now().strftime("%Y-%m-%d")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},parallelize=True",
        "--device", "cuda:0",
        "--batch_size", "8",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    for fname in os.listdir(os.path.join(run_output_dir, model_name.replace('/', '__'))):
        print(fname)
        if fname.startswith(f"results_{day}") and fname.endswith(".json"):
            result_file = os.path.join(run_output_dir, model_name.replace('/', '__'), fname)
            with open(result_file, 'r') as f:
                result = json.load(f)
                acc = result['results'][task_name]['acc,none']
                stderr = result['results'][task_name]['acc_stderr,none']

                wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                              f"{task_name}/accuracy": acc,
                              f"{task_name}/stderr": stderr,
                              "run_index": i + 1
                              })
                print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# wandb: Currently logged in as: xj2193 (med-moe) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250508_023315-d1fa589u</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/d1fa589u' target="_blank">meta-llama_Llama-3.2-3B_pubmedqa_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/d1fa589u' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/d1fa589u</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 38.07 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T02-33-52.291826.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 38.15 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T02-34-30.367918.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 38.71 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T02-35-09.133227.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 38.18 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T02-35-47.160032.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 38.31 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,parallelize=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T02-36-25.565091.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>▁▂█▂▄</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.732</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>38.30669</td></tr><tr><td>pubmedqa/stderr</td><td>0.01983</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/d1fa589u' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/d1fa589u</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250508_023315-d1fa589u/logs</code>

# %% [markdown]
# **🔍 INT8 Quantization (int8)**

# %%
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

from transformers import BitsAndBytesConfig

# 8-bit quantization config
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True
)

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_auth_token=True
)

load_times = []

trials = 5

print(f"⏳ Starting timed model loads ({trials} repetitions)...\n")

for i in range(trials):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        quantization_config=bnb_config,
        use_auth_token=True
    )

    elapsed = time.monotonic() - start_time
    load_times.append(elapsed)
    print(f"✅ Run {i + 1}: Loaded in {elapsed:.2f} seconds")

    if i == trials - 1:
        print(f"\n📦 GPU Memory Snapshot:")
        print(subprocess.getoutput("nvidia-smi"))

    # Clean up between runs (free GPU memory)
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary stats
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (INT8)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Std Dev:           {std_dev_time:.2f} seconds")
# Out:
# ⏳ Starting timed model loads (5 repetitions)...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 17.37 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 17.33 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 17.57 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 18.10 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 16.90 seconds
#
# 📦 GPU Memory Snapshot:
# Thu May  8 03:00:36 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             54W /  400W |   10393MiB /  40960MiB |     28%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (INT8)
# - Average Load Time: 17.46 seconds
# - Std Dev:           0.39 seconds

# %%
# Benchmark int8
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "meta-llama/Llama-3.2-3B"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_int8_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 8,
        "precision": "int8",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_int8_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},load_in_8bit=True",
        "--device", "cuda:0",
        "--batch_size", "8",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    for fname in os.listdir(os.path.join(run_output_dir, model_name.replace('/', '__'))):
        print(fname)
        if fname.startswith(f"results_{day}") and fname.endswith(".json"):
            result_file = os.path.join(run_output_dir, model_name.replace('/', '__'), fname)
            with open(result_file, 'r') as f:
                result = json.load(f)
                acc = result['results'][task_name]['acc,none']
                stderr = result['results'][task_name]['acc_stderr,none']

                wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                              f"{task_name}/accuracy": acc,
                              f"{task_name}/stderr": stderr,
                              "run_index": i + 1
                              })
                print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250508_031641-wf76ay36</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/wf76ay36' target="_blank">meta-llama_Llama-3.2-3B_pubmedqa_int8_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/wf76ay36' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/wf76ay36</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 50.96 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_8bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T03-17-32.127538.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 50.94 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_8bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T03-18-23.029656.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 50.62 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_8bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T03-19-13.609132.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 50.65 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_8bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T03-20-04.332965.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 50.44 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_8bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.732|±  |0.0198|
#
#
# results_2025-05-08T03-20-54.801548.json
# 📈 Logged to W&B: acc=0.732, stderr=0.0198
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>██▃▄▁</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.732</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>50.44041</td></tr><tr><td>pubmedqa/stderr</td><td>0.01983</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_int8_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/wf76ay36' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/wf76ay36</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250508_031641-wf76ay36/logs</code>

# %% [markdown]
# **🔍 INT4 Quantization (int4)**

# %%
model_name = "TsinghuaC3I/Llama-3-8B-UltraMedical"

from transformers import BitsAndBytesConfig

# 8-bit quantization config
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    llm_int4_enable_fp32_cpu_offload=True
)

# Load tokenizer once (doesn’t affect model loading time)
tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True,
    use_auth_token=True
)

load_times = []

trials = 5

print(f"⏳ Starting timed model loads ({trials} repetitions)...\n")

for i in range(trials):
    start_time = time.monotonic()

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        trust_remote_code=True,
        device_map="auto",
        quantization_config=bnb_config,
        use_auth_token=True
    )

    elapsed = time.monotonic() - start_time
    load_times.append(elapsed)
    print(f"✅ Run {i + 1}: Loaded in {elapsed:.2f} seconds")

    if i == trials - 1:
        print(f"\n📦 GPU Memory Snapshot:")
        print(subprocess.getoutput("nvidia-smi"))

    # Clean up between runs (free GPU memory)
    del model
    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(5)
    gc.collect()
    torch.cuda.empty_cache()

# Summary stats
mean_time = np.mean(load_times)
std_dev_time = np.std(load_times)

print(f"\n📊 {model_name} Load Time Summary (INT4)")
print(f"- Average Load Time: {mean_time:.2f} seconds")
print(f"- Std Dev:           {std_dev_time:.2f} seconds")
# Out:
# ⏳ Starting timed model loads (5 repetitions)...
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 1: Loaded in 17.76 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 2: Loaded in 17.21 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 3: Loaded in 17.12 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 4: Loaded in 17.26 seconds
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# ✅ Run 5: Loaded in 17.59 seconds
#
# 📦 GPU Memory Snapshot:
# Thu May  8 03:27:33 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   30C    P0             54W /  400W |    8241MiB /  40960MiB |     26%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+
#
# 📊 TsinghuaC3I/Llama-3-8B-UltraMedical Load Time Summary (INT4)
# - Average Load Time: 17.39 seconds
# - Std Dev:           0.25 seconds

# %%
# Benchmark int4
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "meta-llama/Llama-3.2-3B"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_int4_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 8,
        "precision": "int4",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_int4_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},load_in_4bit=True",
        "--device", "cuda:0",
        "--batch_size", "8",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    for fname in os.listdir(os.path.join(run_output_dir, model_name.replace('/', '__'))):
        print(fname)
        if fname.startswith(f"results_{day}") and fname.endswith(".json"):
            result_file = os.path.join(run_output_dir, model_name.replace('/', '__'), fname)
            with open(result_file, 'r') as f:
                result = json.load(f)
                acc = result['results'][task_name]['acc,none']
                stderr = result['results'][task_name]['acc_stderr,none']

                wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                              f"{task_name}/accuracy": acc,
                              f"{task_name}/stderr": stderr,
                              "run_index": i + 1
                              })
                print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250508_034205-aidwdm94</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/aidwdm94' target="_blank">meta-llama_Llama-3.2-3B_pubmedqa_int4_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/aidwdm94' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/aidwdm94</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 42.74 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.676|±  | 0.021|
#
#
# results_2025-05-08T03-42-47.306817.json
# 📈 Logged to W&B: acc=0.676, stderr=0.0210
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 44.11 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.676|±  | 0.021|
#
#
# results_2025-05-08T03-43-31.326236.json
# 📈 Logged to W&B: acc=0.676, stderr=0.0210
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 42.91 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.676|±  | 0.021|
#
#
# results_2025-05-08T03-44-14.355578.json
# 📈 Logged to W&B: acc=0.676, stderr=0.0210
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 43.35 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.676|±  | 0.021|
#
#
# results_2025-05-08T03-44-57.598523.json
# 📈 Logged to W&B: acc=0.676, stderr=0.0210
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 43.21 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 8
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  |0.676|±  | 0.021|
#
#
# results_2025-05-08T03-45-40.887435.json
# 📈 Logged to W&B: acc=0.676, stderr=0.0210
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>▁█▂▄▃</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.676</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>43.21151</td></tr><tr><td>pubmedqa/stderr</td><td>0.02095</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_int4_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/aidwdm94' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/aidwdm94</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250508_034205-aidwdm94/logs</code>

# %% [markdown]
# With Flash Attention enabled

# %%
# Benchmark int4 with flashattention batch size 32
import random
import json
import wandb
import subprocess
import time
import os
from datetime import datetime

# -----------------------------
# 🧠 Model and Task Config
# -----------------------------
model_name = "meta-llama/Llama-3.2-3B"
task_name = "pubmedqa"
output_base = "./results"

# -----------------------------
# 🚀 Start W&B run
# -----------------------------
run_name = f"{model_name.replace('/', '_')}_{task_name}_int4_flashattention_5x"
wandb_run = wandb.init(
    project="med-moe-baseline-evals",
    name=run_name,
    config={
        "model": model_name,
        "task": task_name,
        "batch_size": 32,
        "precision": "int4",
        "eval_method": "lm_eval",
        "repeats": 5
    }
)

# -----------------------------
# 🔁 Run 5x Evaluation Loop
# -----------------------------
for i in range(5):
    print(f"\n🔁 Run {i + 1}/5")

    # Create timestamped output folder
    timestamp = datetime.now().strftime("%Y-%m-%dT%H-%M-%S")
    run_output_dir = os.path.join(output_base, f"run_{i+1}_int4_{timestamp}")
    os.makedirs(run_output_dir, exist_ok=True)

    # Define lm_eval command
    command = [
        "lm_eval",
        "--model", "hf",
        "--tasks", task_name,
        "--model_args", f"pretrained={model_name},load_in_4bit=True,attn_implementation=flash_attention_2",
        "--device", "cuda:0",
        "--batch_size", "32",
        "--write_out",
        "--output_path", run_output_dir,
        "--trust_remote_code",
        "--confirm_run_unsafe_code"
    ]

    # Start timing
    start_time = time.monotonic()
    result = subprocess.run(command, capture_output=True, text=True)
    elapsed = time.monotonic() - start_time

    print(f"✅ Run {i + 1} completed in {elapsed:.2f} seconds")
    print("STDOUT:\n", result.stdout)

    # -----------------------------
    # 📊 Find and parse result file
    # -----------------------------
    result_file = None
    for fname in os.listdir(os.path.join(run_output_dir, model_name.replace('/', '__'))):
        print(fname)
        if fname.startswith(f"results_{day}") and fname.endswith(".json"):
            result_file = os.path.join(run_output_dir, model_name.replace('/', '__'), fname)
            with open(result_file, 'r') as f:
                result = json.load(f)
                acc = result['results'][task_name]['acc,none']
                stderr = result['results'][task_name]['acc_stderr,none']

                wandb_run.log({f"{task_name}/eval_time_sec": elapsed,
                              f"{task_name}/accuracy": acc,
                              f"{task_name}/stderr": stderr,
                              "run_index": i + 1
                              })
                print(f"📈 Logged to W&B: acc={acc:.3f}, stderr={stderr:.4f}")

    if result_file is None:
        print(f"❌ No eval_results_*.json found in {run_output_dir}")
        continue

# -----------------------------
# ✅ Finish W&B run
# -----------------------------
wandb_run.finish()
# Out:
# Finishing previous runs because reinit is set to 'default'.
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>█▁</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁</td></tr><tr><td>run_index</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.68</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>42.09144</td></tr><tr><td>pubmedqa/stderr</td><td>0.02088</td></tr><tr><td>run_index</td><td>2</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_int4_flashattention_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/3a1plzi6' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/3a1plzi6</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250508_034905-3a1plzi6/logs</code>
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250508_035222-fzadrqj2</code>
# Syncing run <strong><a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fzadrqj2' target="_blank">meta-llama_Llama-3.2-3B_pubmedqa_int4_flashattention_5x</a></strong> to <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a>
#  View run at <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fzadrqj2' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fzadrqj2</a>
# 🔁 Run 1/5
# ✅ Run 1 completed in 41.31 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  | 0.68|±  |0.0209|
#
#
# results_2025-05-08T03-53-03.169400.json
# 📈 Logged to W&B: acc=0.680, stderr=0.0209
#
# 🔁 Run 2/5
# ✅ Run 2 completed in 42.05 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  | 0.68|±  |0.0209|
#
#
# results_2025-05-08T03-53-45.083047.json
# 📈 Logged to W&B: acc=0.680, stderr=0.0209
#
# 🔁 Run 3/5
# ✅ Run 3 completed in 42.30 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  | 0.68|±  |0.0209|
#
#
# results_2025-05-08T03-54-27.510520.json
# 📈 Logged to W&B: acc=0.680, stderr=0.0209
#
# 🔁 Run 4/5
# ✅ Run 4 completed in 41.95 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  | 0.68|±  |0.0209|
#
#
# results_2025-05-08T03-55-09.384541.json
# 📈 Logged to W&B: acc=0.680, stderr=0.0209
#
# 🔁 Run 5/5
# ✅ Run 5 completed in 41.43 seconds
# STDOUT:
#  hf (pretrained=meta-llama/Llama-3.2-3B,load_in_4bit=True,attn_implementation=flash_attention_2,trust_remote_code=True), gen_kwargs: (None), limit: None, num_fewshot: None, batch_size: 32
# | Tasks  |Version|Filter|n-shot|Metric|   |Value|   |Stderr|
# |--------|------:|------|-----:|------|---|----:|---|-----:|
# |pubmedqa|      1|none  |     0|acc   |↑  | 0.68|±  |0.0209|
#
#
# results_2025-05-08T03-55-50.897119.json
# 📈 Logged to W&B: acc=0.680, stderr=0.0209
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>▁▆█▆▂</td></tr><tr><td>pubmedqa/stderr</td><td>▁▁▁▁▁</td></tr><tr><td>run_index</td><td>▁▃▅▆█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>pubmedqa/accuracy</td><td>0.68</td></tr><tr><td>pubmedqa/eval_time_sec</td><td>41.42885</td></tr><tr><td>pubmedqa/stderr</td><td>0.02088</td></tr><tr><td>run_index</td><td>5</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">meta-llama_Llama-3.2-3B_pubmedqa_int4_flashattention_5x</strong> at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fzadrqj2' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals/runs/fzadrqj2</a><br> View project at: <a href='https://wandb.ai/med-moe/med-moe-baseline-evals' target="_blank">https://wandb.ai/med-moe/med-moe-baseline-evals</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250508_035222-fzadrqj2/logs</code>
